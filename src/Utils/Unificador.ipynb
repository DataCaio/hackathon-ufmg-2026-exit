# %%
import pandas as pd

# %%
resultados_dos_processos = 'data/Hackaton_Enter_Base_Candidatos_Resultados_dos_processos.csv'
df_resultados_dos_processos = pd.read_csv(resultados_dos_processos)
subsidios_disponibilizados = 'data/Hackaton_Enter_Base_Candidatos_Subsídios_disponibilizados.csv'
df_subsidios_disponibilizados = pd.read_csv(subsidios_disponibilizados, header = 1)

# %%
df_resultados_dos_processos.head()
# Out:
#           Número do processo  UF                 Assunto Sub-assunto  \
# 0  1764352-89.2025.8.06.1818  CE  Não reconhece operação    Genérico
# 1  5638325-36.2025.8.17.4124  PE  Não reconhece operação       Golpe
# 2  1037491-89.2025.8.18.1658  PI  Não reconhece operação       Golpe
# 3  9547931-23.2025.8.04.4188  AM  Não reconhece operação       Golpe
# 4  9999446-69.2025.8.04.4264  AM  Não reconhece operação       Golpe
#
#   Resultado macro      Resultado micro Valor da causa  \
# 0       Não Êxito  Parcial procedência      13.534,00
# 1       Não Êxito  Parcial procedência       7.883,63
# 2       Não Êxito  Parcial procedência       8.561,97
# 3           Êxito        Improcedência       5.693,13
# 4           Êxito        Improcedência       8.515,67
#
#   Valor da condenação/indenização
# 0                        7.714,38
# 1                        3.784,14
# 2                        6.507,10
# 3                            0,00
# 4                            0,00

# %%
df_subsidios_disponibilizados.head()
# Out:
#           Número do processo  Contrato  Extrato  Comprovante de crédito  \
# 0  1764352-89.2025.8.06.1818         0        0                       0
# 1  5638325-36.2025.8.17.4124         1        1                       0
# 2  1037491-89.2025.8.18.1658         0        1                       1
# 3  9547931-23.2025.8.04.4188         1        1                       1
# 4  9999446-69.2025.8.04.4264         0        1                       0
#
#    Dossiê  Demonstrativo de evolução da dívida  Laudo referenciado
# 0       1                                    1                   1
# 1       1                                    1                   1
# 2       1                                    1                   0
# 3       1                                    1                   0
# 4       1                                    1                   1

# %%
#Unificação do Banco de Dados
df_unificado = df_resultados_dos_processos.merge(
    df_subsidios_disponibilizados,
    on='Número do processo',
    how='left'  # ou 'inner', dependendo do caso
)

# %%
df_unificado.head()
# Out:
#           Número do processo  UF                 Assunto Sub-assunto  \
# 0  1764352-89.2025.8.06.1818  CE  Não reconhece operação    Genérico
# 1  5638325-36.2025.8.17.4124  PE  Não reconhece operação       Golpe
# 2  1037491-89.2025.8.18.1658  PI  Não reconhece operação       Golpe
# 3  9547931-23.2025.8.04.4188  AM  Não reconhece operação       Golpe
# 4  9999446-69.2025.8.04.4264  AM  Não reconhece operação       Golpe
#
#   Resultado macro      Resultado micro Valor da causa  \
# 0       Não Êxito  Parcial procedência      13.534,00
# 1       Não Êxito  Parcial procedência       7.883,63
# 2       Não Êxito  Parcial procedência       8.561,97
# 3           Êxito        Improcedência       5.693,13
# 4           Êxito        Improcedência       8.515,67
#
#   Valor da condenação/indenização  Contrato  Extrato  Comprovante de crédito  \
# 0                        7.714,38         0        0                       0
# 1                        3.784,14         1        1                       0
# 2                        6.507,10         0        1                       1
# 3                            0,00         1        1                       1
# 4                            0,00         0        1                       0
#
#    Dossiê  Demonstrativo de evolução da dívida  Laudo referenciado
# 0       1                                    1                   1
# 1       1                                    1                   1
# 2       1                                    1                   0
# 3       1                                    1                   0
# 4       1                                    1                   1

# %%
df_unificado["Resultado macro"]  = df_unificado["Resultado macro"].map({"Não Êxito": 0, "Êxito": 1})
df_unificado
# Out:
#               Número do processo  UF                 Assunto Sub-assunto  \
# 0      1764352-89.2025.8.06.1818  CE  Não reconhece operação    Genérico
# 1      5638325-36.2025.8.17.4124  PE  Não reconhece operação       Golpe
# 2      1037491-89.2025.8.18.1658  PI  Não reconhece operação       Golpe
# 3      9547931-23.2025.8.04.4188  AM  Não reconhece operação       Golpe
# 4      9999446-69.2025.8.04.4264  AM  Não reconhece operação       Golpe
# ...                          ...  ..                     ...         ...
# 59995  5948422-40.2025.8.25.9205  SE  Não reconhece operação    Genérico
# 59996  7271337-72.2025.8.17.3193  PE  Não reconhece operação       Golpe
# 59997  8668390-32.2025.8.01.9603  AC  Não reconhece operação    Genérico
# 59998  8052515-88.2025.8.07.3354  DF  Não reconhece operação    Genérico
# 59999  6936655-34.2025.8.26.1473  SP  Não reconhece operação       Golpe
#
#        Resultado macro      Resultado micro Valor da causa  \
# 0                    0  Parcial procedência      13.534,00
# 1                    0  Parcial procedência       7.883,63
# 2                    0  Parcial procedência       8.561,97
# 3                    1        Improcedência       5.693,13
# 4                    1        Improcedência       8.515,67
# ...                ...                  ...            ...
# 59995                1             Extinção      11.777,37
# 59996                1             Extinção      16.575,93
# 59997                0  Parcial procedência      20.517,82
# 59998                1        Improcedência      14.069,63
# 59999                1        Improcedência      14.771,05
#
#       Valor da condenação/indenização  Contrato  Extrato  \
# 0                            7.714,38         0        0
# 1                            3.784,14         1        1
# 2                            6.507,10         0        1
# 3                                0,00         1        1
# 4                                0,00         0        1
# ...                               ...       ...      ...
# 59995                            0,00         1        1
# 59996                            0,00         1        1
# 59997                       14.157,30         0        1
# 59998                            0,00         1        1
# 59999                            0,00         1        1
#
#        Comprovante de crédito  Dossiê  Demonstrativo de evolução da dívida  \
# 0                           0       1                                    1
# 1                           0       1                                    1
# 2                           1       1                                    1
# 3                           1       1                                    1
# 4                           0       1                                    1
# ...                       ...     ...                                  ...
# 59995                       0       1                                    1
# 59996                       1       0                                    0
# 59997                       0       1                                    1
# 59998                       1       0                                    0
# 59999                       1       1                                    1
#
#        Laudo referenciado
# 0                       1
# 1                       1
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 59995                   1
# 59996                   1
# 59997                   1
# 59998                   1
# 59999                   1
#
# [60000 rows x 14 columns]

# %%
df_unificado.head()
# Out:
#               Número do processo  UF                 Assunto Sub-assunto  \
# 0      1764352-89.2025.8.06.1818  CE  Não reconhece operação    Genérico
# 1      5638325-36.2025.8.17.4124  PE  Não reconhece operação       Golpe
# 2      1037491-89.2025.8.18.1658  PI  Não reconhece operação       Golpe
# 3      9547931-23.2025.8.04.4188  AM  Não reconhece operação       Golpe
# 4      9999446-69.2025.8.04.4264  AM  Não reconhece operação       Golpe
# ...                          ...  ..                     ...         ...
# 59995  5948422-40.2025.8.25.9205  SE  Não reconhece operação    Genérico
# 59996  7271337-72.2025.8.17.3193  PE  Não reconhece operação       Golpe
# 59997  8668390-32.2025.8.01.9603  AC  Não reconhece operação    Genérico
# 59998  8052515-88.2025.8.07.3354  DF  Não reconhece operação    Genérico
# 59999  6936655-34.2025.8.26.1473  SP  Não reconhece operação       Golpe
#
#        Resultado macro      Resultado micro Valor da causa  \
# 0                    0  Parcial procedência      13.534,00
# 1                    0  Parcial procedência       7.883,63
# 2                    0  Parcial procedência       8.561,97
# 3                    1        Improcedência       5.693,13
# 4                    1        Improcedência       8.515,67
# ...                ...                  ...            ...
# 59995                1             Extinção      11.777,37
# 59996                1             Extinção      16.575,93
# 59997                0  Parcial procedência      20.517,82
# 59998                1        Improcedência      14.069,63
# 59999                1        Improcedência      14.771,05
#
#       Valor da condenação/indenização  Contrato  Extrato  \
# 0                            7.714,38         0        0
# 1                            3.784,14         1        1
# 2                            6.507,10         0        1
# 3                                0,00         1        1
# 4                                0,00         0        1
# ...                               ...       ...      ...
# 59995                            0,00         1        1
# 59996                            0,00         1        1
# 59997                       14.157,30         0        1
# 59998                            0,00         1        1
# 59999                            0,00         1        1
#
#        Comprovante de crédito  Dossiê  Demonstrativo de evolução da dívida  \
# 0                           0       1                                    1
# 1                           0       1                                    1
# 2                           1       1                                    1
# 3                           1       1                                    1
# 4                           0       1                                    1
# ...                       ...     ...                                  ...
# 59995                       0       1                                    1
# 59996                       1       0                                    0
# 59997                       0       1                                    1
# 59998                       1       0                                    0
# 59999                       1       1                                    1
#
#        Laudo referenciado
# 0                       1
# 1                       1
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 59995                   1
# 59996                   1
# 59997                   1
# 59998                   1
# 59999                   1
#
# [60000 rows x 14 columns]

# %%
df_unificado.to_csv('data/Hackaton_Enter_Banco_unificado.csv', index=False)
